# %% [markdown]
# <a href="https://colab.research.google.com/github/FerranBadal/Extraccion-de-Datos/blob/main/1_Extracci%C3%B3n_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a50cafeb-05c0-4763-9cff-a5abe26470cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a50cafeb-05c0-4763-9cff-a5abe26470cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Convertir en dataframe
df= pd.read_csv("CountryTable.csv")
#df

# %%
#Imprimimos las primeras filas o registros del Dataframe
df.head(5)
# Out:
#   code         name      continent                     region  surface_area  \
# 0  ABW        Aruba  North America                  Caribbean         193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia      652090.0
# 2  AGO       Angola         Africa             Central Africa     1246700.0
# 3  AIA     Anguilla  North America                  Caribbean          96.0
# 4  ALB      Albania         Europe            Southern Europe       28748.0
#
#    independence_year  population  life_expectancy     gnp  gnp_old  \
# 0                NaN      103000             78.4   828.0    793.0
# 1             1919.0    22720000             45.9  5976.0      NaN
# 2             1975.0    12878000             38.3  6648.0   7984.0
# 3                NaN        8000             76.1    63.2      NaN
# 4             1912.0     3401200             71.6  3205.0   2500.0
#
#               local_name                               government_form  \
# ...

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUALITATIVAS **

# %%
#Filtro por objeto

#Aqui se arrojan solo los datos de países que esten en Europa
filtro1=df[df["continent"] == "Europe"]
filtro1
# Out:
#     code                           name continent            region  \
# 4    ALB                        Albania    Europe   Southern Europe
# 5    AND                        Andorra    Europe   Southern Europe
# 15   AuT                        Austria    Europe    Western Europe
# 18   BEL                        Belgium    Europe    Western Europe
# 22   BGR                       Bulgaria    Europe    Eastern Europe
# 25   BIH         Bosnia and Herzegovina    Europe   Southern Europe
# 26   BLR                        Belarus    Europe    Eastern Europe
# 39   CHE                    Switzerland    Europe    Western Europe
# 55   CZE                 Czech Republic    Europe    Eastern Europe
# 56   DEu                        Germany    Europe    Western Europe
# 59   DNK                        Denmark    Europe  Nordic Countries
# 66   ESP                          Spain    Europe   Southern Europe
# 67   EST                        Estonia    Europe  Baltic Countries
# ...

# %%
filtro1.to_csv("Filtro1.csv")

# %%
#Filtro por filas

#Aqui se arrojan datos de la fila 10 a la 16
filtro2=df.iloc[ 10:16 , : ]  #filas no consecutivas
filtro2
# Out:
#    code                         name      continent  \
# 10  ASM               American Samoa        Oceania
# 11  ATA                   Antarctica     Antarctica
# 12  ATF  French Southern territories     Antarctica
# 13  ATG          Antigua and Barbuda  North America
# 14  AuS                    Australia        Oceania
# 15  AuT                      Austria         Europe
#
#                        region  surface_area  independence_year  population  \
# 10                  Polynesia         199.0                NaN       68000
# 11                 Antarctica    13120000.0                NaN           0
# 12                 Antarctica        7780.0                NaN           0
# 13                  Caribbean         442.0             1981.0       68000
# 14  Australia and New Zealand     7741220.0             1901.0    18886000
# 15             Western Europe       83859.0             1918.0     8091800
#
# ...

# %%
filtro2.to_csv("Filtro2.csv")

# %%
#Filtro por columnas

#Aqui se arrojan datos de la fila 1, 4 y 6
filtro3=df.iloc[ : , [1,4,6]]  #columnas no consecutivas
filtro3
# Out:
#              name  surface_area  population
# 0           Aruba         193.0      103000
# 1     Afghanistan      652090.0    22720000
# 2          Angola     1246700.0    12878000
# 3        Anguilla          96.0        8000
# 4         Albania       28748.0     3401200
# ..            ...           ...         ...
# 234         Yemen      527968.0    18112000
# 235    Yugoslavia      102173.0    10640000
# 236  South Africa     1221037.0    40377000
# 237        Zambia      752618.0     9169000
# 238      Zimbabwe      390757.0    11669000
#
# [239 rows x 3 columns]

# %%
filtro3.to_csv("Filtro3.csv")

# %%
df= pd.read_csv("CountryTable.csv", index_col=1)
df
#Aqui establecemos la columna "name" como el index
# Out:
#              code      continent                     region  surface_area  \
# name
# Aruba         ABW  North America                  Caribbean         193.0
# Afghanistan   AFG           Asia  Southern and Central Asia      652090.0
# Angola        AGO         Africa             Central Africa     1246700.0
# Anguilla      AIA  North America                  Caribbean          96.0
# Albania       ALB         Europe            Southern Europe       28748.0
# ...           ...            ...                        ...           ...
# Yemen         YEM           Asia                Middle East      527968.0
# Yugoslavia    YuG         Europe            Southern Europe      102173.0
# South Africa  ZAF         Africa            Southern Africa     1221037.0
# Zambia        ZMB         Africa             Eastern Africa      752618.0
# Zimbabwe      ZWE         Africa             Eastern Africa      390757.0
#
#               independence_year  population  life_expectancy       gnp  \
# ...

# %%
#Paso 2: Aplicamos Filtro de filas vs columnas

#Aqui obtenemos datos de la poblacion de mexico y españa
filtro4=df.loc[["Mexico","Spain"], ["population"]]
filtro4
# Out:
#         population
# name
# Mexico    98881000
# Spain     39441700

# %%
filtro4.to_csv("Filtro4.csv")

# %%
#Filtro por cabecera

#Aqui solo nos arroja las primeras 10 filas
filtro5=df.head(10)
filtro5
# Out:
#                      code      continent                     region  \
# name
# Aruba                 ABW  North America                  Caribbean
# Afghanistan           AFG           Asia  Southern and Central Asia
# Angola                AGO         Africa             Central Africa
# Anguilla              AIA  North America                  Caribbean
# Albania               ALB         Europe            Southern Europe
# Andorra               AND         Europe            Southern Europe
# Netherlands Antilles  ANT  North America                  Caribbean
# united Arab Emirates  ARE           Asia                Middle East
# Argentina             ARG  South America              South America
# Armenia               ARM           Asia                Middle East
#
#                       surface_area  independence_year  population  \
# name
# Aruba                        193.0                NaN      103000
# Afghanistan               652090.0             1919.0    22720000
# ...

# %%
filtro5.to_csv("Filtro5.csv")

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUANTITATIVAS**

# %%
#Filtro por comparacion

#Aqui solo observamos datos de países con poblacion mayor a 100 millones
filtro6=df[df["population"] > 100000000]
filtro6
# Out:
#                    code      continent                     region  \
# name
# Bangladesh          BGD           Asia  Southern and Central Asia
# Brazil              BRA  South America              South America
# China               CHN           Asia               Eastern Asia
# Indonesia           IDN           Asia             Southeast Asia
# India               IND           Asia  Southern and Central Asia
# Japan               JPN           Asia               Eastern Asia
# Nigeria             NGA         Africa             Western Africa
# Pakistan            PAK           Asia  Southern and Central Asia
# Russian Federation  RuS         Europe             Eastern Europe
# united States       uSA  North America              North America
#
#                     surface_area  independence_year  population  \
# name
# Bangladesh              143998.0             1971.0   129155000
# Brazil                 8547403.0             1822.0   170115000
# ...

# %%
filtro6.to_csv("Filtro6.csv")

# %% [markdown]
# **FILTROS BASICOS CON CONETORES LOGICOS**

# %%
#Filtro Y

#Aqui solo observamos datos de países con poblacion mayor a 100 millones y que esten en Ásia

filtro7=df[(df["population"] > 100000000) & (df["continent"] == "Asia")]
filtro7
# Out:
#            code continent                     region  surface_area  \
# name
# Bangladesh  BGD      Asia  Southern and Central Asia      143998.0
# China       CHN      Asia               Eastern Asia     9572900.0
# Indonesia   IDN      Asia             Southeast Asia     1904569.0
# India       IND      Asia  Southern and Central Asia     3287263.0
# Japan       JPN      Asia               Eastern Asia      377829.0
# Pakistan    PAK      Asia  Southern and Central Asia      796095.0
#
#             independence_year  population  life_expectancy        gnp  \
# name
# Bangladesh             1971.0   129155000             60.2    32852.0
# China                 -1523.0  1277558000             71.4   982268.0
# Indonesia              1945.0   212107000             68.0    84982.0
# India                  1947.0  1013662000             62.5   447114.0
# Japan                  -660.0   126714000             80.7  3787042.0
# ...

# %%
filtro7.to_csv("Filtro7.csv")

# %%
#Filtro o

#Aqui solo observamos datos de países con poblacion mayor a 100 millones o que esten en Ásia

filtro8=df[(df["population"] > 100000000) | (df["continent"] == "Asia")]
filtro8
# Out:
#                      code      continent                     region  \
# name
# Afghanistan           AFG           Asia  Southern and Central Asia
# united Arab Emirates  ARE           Asia                Middle East
# Armenia               ARM           Asia                Middle East
# Azerbaijan            AZE           Asia                Middle East
# Bangladesh            BGD           Asia  Southern and Central Asia
# Bahrain               BHR           Asia                Middle East
# Brazil                BRA  South America              South America
# Brunei                BRN           Asia             Southeast Asia
# Bhutan                BTN           Asia  Southern and Central Asia
# China                 CHN           Asia               Eastern Asia
# Cyprus                CYP           Asia                Middle East
# Georgia               GEO           Asia                Middle East
# Hong Kong             HKG           Asia               Eastern Asia
# ...

# %%
filtro8.to_csv("Filtro8.csv")

# %%
#Filtro not

#Aqui no observamos datos de países con poblacion mayor a 100 millones y que esten en Ásia

filtro9=df[~(df["population"] >= 100000000) & ~(df["continent"] == "Asia")]
filtro9
# Out:
#              code      continent           region  surface_area  \
# name
# Aruba         ABW  North America        Caribbean         193.0
# Angola        AGO         Africa   Central Africa     1246700.0
# Anguilla      AIA  North America        Caribbean          96.0
# Albania       ALB         Europe  Southern Europe       28748.0
# Andorra       AND         Europe  Southern Europe         468.0
# ...           ...            ...              ...           ...
# Samoa         WSM        Oceania        Polynesia        2831.0
# Yugoslavia    YuG         Europe  Southern Europe      102173.0
# South Africa  ZAF         Africa  Southern Africa     1221037.0
# Zambia        ZMB         Africa   Eastern Africa      752618.0
# Zimbabwe      ZWE         Africa   Eastern Africa      390757.0
#
#               independence_year  population  life_expectancy       gnp  \
# name
# Aruba                       NaN      103000             78.4     828.0
# ...

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("Filtro9.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files

#Aqui descargamos todos los arvhivos de los filtros
files.download("Filtro1.csv")
files.download("Filtro2.csv")
files.download("Filtro3.csv")
files.download("Filtro4.csv")
files.download("Filtro5.csv")
files.download("Filtro6.csv")
files.download("Filtro7.csv")
files.download("Filtro8.csv")
files.download("Filtro9.csv")
